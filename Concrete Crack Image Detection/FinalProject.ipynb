# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

 

import os
import itertools
from glob import glob
import PIL
from PIL import Image
from scipy import ndimage 
import scipy
import sys

 

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

 

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.layers.normalization import BatchNormalization

 

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
import scipy
from scipy import ndimage
import scipy.misc
import imageio
import numpy
import matplotlib as plt
from matplotlib.pyplot import imread
# Out:
# Using TensorFlow backend.

# %%
train_data_dir_positive = "C:/Users/kandr/Desktop/concerete_crack_images/concerete_crack_images/training/Positive/"
train_data_dir_negative = "C:/Users/kandr/Desktop/concerete_crack_images/concerete_crack_images/training/Negative/"

train_imgs_p = os.listdir(train_data_dir_positive)
train_imgs_n = os.listdir(train_data_dir_negative)
print(len(train_imgs_p))
print(len(train_imgs_n))
# Out:
# 16070
# 16037

# %%
import imageio
import scipy.misc
num_px = 64

def extractFeaturesAndLabels(dir, impg_dataset, category):
  X = np.zeros((len(impg_dataset), num_px*num_px*3))
  y = np.zeros((len(impg_dataset)))
  for i in range(0,len(impg_dataset)) :
    #Read an image from a file as an array.
    #The different colour bands/channels are stored 
    #in the third dimension, such that a 
    #grey-image is MxN, an RGB-image MxNx3 
    image = np.array(imageio.imread(dir + impg_dataset[i])) 
    #image = np.array(imageio.imread(dir + impg_dataset[i])) 
    
    # Resize the image. Size of the output image (height, width)
    image = scipy.misc.imresize(image, size=(num_px, num_px))
    
    # Convert the matrix to a vector
    image = image.reshape((1, num_px*num_px*3)).T     

    # Note that RGB (Red, Green, Blue) are 8 bit each.
    # Hence, the range for each individual colour is 0-255 (as 2^8 = 256 possibilities).
    # By dividing by 255, Convert the 0-255 range to a 0.0-1.0 range where 0.0 means 0 (0x00) and 1.0 means 255 (0xFF).
    image = image/255.0
    
    image = image.reshape((num_px*num_px*3,1))
    for j in range(0,num_px*num_px*3) :
        X[i][j] = image[j][0]
        
    if category == 'positive':
        y[i] = 1
    else:
        y[i] = 0

  y = y.astype(int)
  
  return(X, y)

def get_accuracy(model, X, y):
  y_pred = model.predict(X)

  if sys.version_info < (3, 0):
      accuracy = ((np.sum(y == y_pred, axis=0)).astype('float') /
            X.shape[0])
  else:
      accuracy = np.sum(y == y_pred, axis=0) / X.shape[0]

  #print('Accuracy: %.2f%%' % (accuracy * 100))
  
  return(accuracy * 100)

# %%
X_train_p, y_train_p = extractFeaturesAndLabels(train_data_dir_positive, train_imgs_p, 'positive')
X_train_n, y_train_n = extractFeaturesAndLabels(train_data_dir_negative, train_imgs_n, 'negative')
X_train_mixed = np.concatenate([X_train_p,X_train_n])
y_train_mixed = np.concatenate([y_train_p,y_train_n])
# Out:
# C:\Users\kandr\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train_mixed, y_train_mixed, test_size=0.25, random_state=1)

# %%
import numpy as np
from scipy.special import expit
import sys


class NeuralNetMLP(object):
    """ Feedforward neural network / Multi-layer perceptron classifier.

    Parameters
    ------------
    n_output : int
        Number of output units, should be equal to the
        number of unique class labels.
    n_features : int
        Number of features (dimensions) in the target dataset.
        Should be equal to the number of columns in the X array.
    n_hidden : int (default: 30)
        Number of hidden units.
    l1 : float (default: 0.0)
        Lambda value for L1-regularization.
        No regularization if l1=0.0 (default)
    l2 : float (default: 0.0)
        Lambda value for L2-regularization.
        No regularization if l2=0.0 (default)
    epochs : int (default: 500)
        Number of passes over the training set.
    eta : float (default: 0.001)
        Learning rate.
    alpha : float (default: 0.0)
        Momentum constant. Factor multiplied with the
        gradient of the previous epoch t-1 to improve
        learning speed
        w(t) := w(t) - (grad(t) + alpha*grad(t-1))
    decrease_const : float (default: 0.0)
        Decrease constant. Shrinks the learning rate
        after each epoch via eta / (1 + epoch*decrease_const)
    shuffle : bool (default: True)
        Shuffles training data every epoch if True to prevent circles.
    minibatches : int (default: 1)
        Divides training data into k minibatches for efficiency.
        Normal gradient descent learning if k=1 (default).
    random_state : int (default: None)
        Set random state for shuffling and initializing the weights.

    Attributes
    -----------
    cost_ : list
      Sum of squared errors after each epoch.

    """
    def __init__(self, n_output, n_features, n_hidden=30,
                 l1=0.0, l2=0.0, epochs=500, eta=0.001,
                 alpha=0.0, decrease_const=0.0, shuffle=True,
                 minibatches=1, random_state=None):

        np.random.seed(random_state)
        self.n_output = n_output
        self.n_features = n_features
        self.n_hidden = n_hidden
        self.w1, self.w2 = self._initialize_weights()
        self.l1 = l1
        self.l2 = l2
        self.epochs = epochs
        self.eta = eta
        self.alpha = alpha
        self.decrease_const = decrease_const
        self.shuffle = shuffle
        self.minibatches = minibatches

    def _encode_labels(self, y, k):
        """Encode labels into one-hot representation

        Parameters
        ------------
        y : array, shape = [n_samples]
            Target values.

        Returns
        -----------
        onehot : array, shape = (n_labels, n_samples)

        """
        onehot = np.zeros((k, y.shape[0]))
        for idx, val in enumerate(y):
            onehot[val, idx] = 1.0
        return onehot

    def _initialize_weights(self):
        """Initialize weights with small random numbers."""
        w1 = np.random.uniform(-1.0, 1.0,
                               size=self.n_hidden*(self.n_features + 1))
        w1 = w1.reshape(self.n_hidden, self.n_features + 1)
        w2 = np.random.uniform(-1.0, 1.0,
                               size=self.n_output*(self.n_hidden + 1))
        w2 = w2.reshape(self.n_output, self.n_hidden + 1)
        return w1, w2

    def _sigmoid(self, z):
        """Compute logistic function (sigmoid)

        Uses scipy.special.expit to avoid overflow
        error for very small input values z.

        """
        # return 1.0 / (1.0 + np.exp(-z))
        return expit(z)

    def _sigmoid_gradient(self, z):
        """Compute gradient of the logistic function"""
        sg = self._sigmoid(z)
        return sg * (1.0 - sg)

    def _add_bias_unit(self, X, how='column'):
        """Add bias unit (column or row of 1s) to array at index 0"""
        if how == 'column':
            X_new = np.ones((X.shape[0], X.shape[1] + 1))
            X_new[:, 1:] = X
        elif how == 'row':
            X_new = np.ones((X.shape[0] + 1, X.shape[1]))
            X_new[1:, :] = X
        else:
            raise AttributeError('`how` must be `column` or `row`')
        return X_new

    def _feedforward(self, X, w1, w2):
        """Compute feedforward step

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.

        Returns
        ----------
        a1 : array, shape = [n_samples, n_features+1]
            Input values with bias unit.
        z2 : array, shape = [n_hidden, n_samples]
            Net input of hidden layer.
        a2 : array, shape = [n_hidden+1, n_samples]
            Activation of hidden layer.
        z3 : array, shape = [n_output_units, n_samples]
            Net input of output layer.
        a3 : array, shape = [n_output_units, n_samples]
            Activation of output layer.

        """
        a1 = self._add_bias_unit(X, how='column')
        z2 = w1.dot(a1.T)
        a2 = self._sigmoid(z2)
        a2 = self._add_bias_unit(a2, how='row')
        z3 = w2.dot(a2)
        a3 = self._sigmoid(z3)
        return a1, z2, a2, z3, a3

    def _L2_reg(self, lambda_, w1, w2):
        """Compute L2-regularization cost"""
        return (lambda_/2.0) * (np.sum(w1[:, 1:] ** 2) +
                                np.sum(w2[:, 1:] ** 2))

    def _L1_reg(self, lambda_, w1, w2):
        """Compute L1-regularization cost"""
        return (lambda_/2.0) * (np.abs(w1[:, 1:]).sum() +
                                np.abs(w2[:, 1:]).sum())

    def _get_cost(self, y_enc, output, w1, w2):
        """Compute cost function.

        Parameters
        ----------
        y_enc : array, shape = (n_labels, n_samples)
            one-hot encoded class labels.
        output : array, shape = [n_output_units, n_samples]
            Activation of the output layer (feedforward)
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.

        Returns
        ---------
        cost : float
            Regularized cost.

        """
        term1 = -y_enc * (np.log(output))
        term2 = (1.0 - y_enc) * np.log(1.0 - output)
        cost = np.sum(term1 - term2)
        L1_term = self._L1_reg(self.l1, w1, w2)
        L2_term = self._L2_reg(self.l2, w1, w2)
        cost = cost + L1_term + L2_term
        return cost

    def _get_gradient(self, a1, a2, a3, z2, y_enc, w1, w2):
        """ Compute gradient step using backpropagation.

        Parameters
        ------------
        a1 : array, shape = [n_samples, n_features+1]
            Input values with bias unit.
        a2 : array, shape = [n_hidden+1, n_samples]
            Activation of hidden layer.
        a3 : array, shape = [n_output_units, n_samples]
            Activation of output layer.
        z2 : array, shape = [n_hidden, n_samples]
            Net input of hidden layer.
        y_enc : array, shape = (n_labels, n_samples)
            one-hot encoded class labels.
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.

        Returns
        ---------
        grad1 : array, shape = [n_hidden_units, n_features]
            Gradient of the weight matrix w1.
        grad2 : array, shape = [n_output_units, n_hidden_units]
            Gradient of the weight matrix w2.

        """
        # backpropagation
        sigma3 = a3 - y_enc
        z2 = self._add_bias_unit(z2, how='row')
        sigma2 = w2.T.dot(sigma3) * self._sigmoid_gradient(z2)
        sigma2 = sigma2[1:, :]
        grad1 = sigma2.dot(a1)
        grad2 = sigma3.dot(a2.T)

        # regularize
        grad1[:, 1:] += self.l2 * w1[:, 1:]
        grad1[:, 1:] += self.l1 * np.sign(w1[:, 1:])
        grad2[:, 1:] += self.l2 * w2[:, 1:]
        grad2[:, 1:] += self.l1 * np.sign(w2[:, 1:])

        return grad1, grad2

    def predict(self, X):
        """Predict class labels

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.

        Returns:
        ----------
        y_pred : array, shape = [n_samples]
            Predicted class labels.

        """
        if len(X.shape) != 2:
            raise AttributeError('X must be a [n_samples, n_features] array.\n'
                                 'Use X[:,None] for 1-feature classification,'
                                 '\nor X[[i]] for 1-sample classification')

        a1, z2, a2, z3, a3 = self._feedforward(X, self.w1, self.w2)
        y_pred = np.argmax(z3, axis=0)
        return y_pred

    def fit(self, X, y, print_progress=False):
        """ Learn weights from training data.

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.
        y : array, shape = [n_samples]
            Target class labels.
        print_progress : bool (default: False)
            Prints progress as the number of epochs
            to stderr.

        Returns:
        ----------
        self

        """
        self.cost_ = []
        X_data, y_data = X.copy(), y.copy()
        y_enc = self._encode_labels(y, self.n_output)

        delta_w1_prev = np.zeros(self.w1.shape)
        delta_w2_prev = np.zeros(self.w2.shape)

        for i in range(self.epochs):

            # adaptive learning rate
            self.eta /= (1 + self.decrease_const*i)

            if print_progress:
                sys.stderr.write('\rEpoch: %d/%d' % (i+1, self.epochs))
                sys.stderr.flush()

            if self.shuffle:
                idx = np.random.permutation(y_data.shape[0])
                X_data, y_enc = X_data[idx], y_enc[:, idx]

            mini = np.array_split(range(y_data.shape[0]), self.minibatches)
            for idx in mini:

                # feedforward
                a1, z2, a2, z3, a3 = self._feedforward(X_data[idx],
                                                       self.w1,
                                                       self.w2)
                cost = self._get_cost(y_enc=y_enc[:, idx],
                                      output=a3,
                                      w1=self.w1,
                                      w2=self.w2)
                self.cost_.append(cost)

                # compute gradient via backpropagation
                grad1, grad2 = self._get_gradient(a1=a1, a2=a2,
                                                  a3=a3, z2=z2,
                                                  y_enc=y_enc[:, idx],
                                                  w1=self.w1,
                                                  w2=self.w2)

                delta_w1, delta_w2 = self.eta * grad1, self.eta * grad2
                self.w1 -= (delta_w1 + (self.alpha * delta_w1_prev))
                self.w2 -= (delta_w2 + (self.alpha * delta_w2_prev))
                delta_w1_prev, delta_w2_prev = delta_w1, delta_w2

        return self

# %% [markdown]
# # NeuralNet MLP

# %%
nn = NeuralNetMLP(n_output=2, 
                  n_features=x_train.shape[1], 
                  n_hidden=10,
                  l2=0.1, 
                  l1=0.1, 
                  epochs=50, 
                  eta=0.0001,
                  alpha=0.1, 
                  decrease_const=0.00001,
                  minibatches=100, 
                  shuffle=True,
                  random_state=1)

nn.fit(x_train, y_train, print_progress=True)

batches = np.array_split(range(len(nn.cost_)), 1000)
cost_ary = np.array(nn.cost_)
cost_avgs = [np.mean(cost_ary[i]) for i in batches]

plt.plot(range(len(cost_avgs)), cost_avgs, color='red')
plt.ylim([0, 6000])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.tight_layout()
#plt.savefig('./figures/cost2.png', dpi=300)
plt.show()

training_accuracy=get_accuracy(nn, x_train, y_train)
print('Training accuracy: %.2f%%' %training_accuracy)

test_accuracy=get_accuracy(nn, x_test, y_test)
print('Test accuracy: %.2f%%' %test_accuracy)

import matplotlib.pyplot as plt

batches = np.array_split(range(len(nn.cost_)), 1000)
cost_ary = np.array(nn.cost_)
cost_avgs = [np.mean(cost_ary[i]) for i in batches]
plt.plot(range(len(cost_avgs)), cost_avgs, color='red')
plt.ylim([0, 6000])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.tight_layout()
#plt.savefig('./figures/cost2.png', dpi=300)
plt.show()

training_accuracy=get_accuracy(nn, x_train, y_train)
print('Training accuracy: %.2f%%' %training_accuracy)

test_accuracy=get_accuracy(nn, x_test, y_test)
print('Test accuracy: %.2f%%' %test_accuracy)
# Out:
# Epoch: 50/50
# Training accuracy: 90.32%
# Test accuracy: 89.47%
# Training accuracy: 90.32%
# Test accuracy: 89.47%

# %%
nn1 = NeuralNetMLP(n_output=2, 
                  n_features=x_train.shape[1], 
                  n_hidden=10,
                  l2=0.1, 
                  l1=0.1, 
                  epochs=100, 
                  eta=0.0001,
                  alpha=0.1, 
                  decrease_const=0.00001,
                  minibatches=100, 
                  shuffle=True,
                  random_state=1)

nn1.fit(x_train, y_train, print_progress=True)

batches = np.array_split(range(len(nn1.cost_)), 1000)
cost_ary = np.array(nn1.cost_)
cost_avgs = [np.mean(cost_ary[i]) for i in batches]

plt.plot(range(len(cost_avgs)), cost_avgs, color='red')
plt.ylim([0, 6000])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.tight_layout()
#plt.savefig('./figures/cost2.png', dpi=300)
plt.show()

training_accuracy=get_accuracy(nn1, x_train, y_train)
print('Training accuracy: %.2f%%' %training_accuracy)

test_accuracy=get_accuracy(nn1, x_test, y_test)
print('Test accuracy: %.2f%%' %test_accuracy)

import matplotlib.pyplot as plt

batches = np.array_split(range(len(nn1.cost_)), 1000)
cost_ary = np.array(nn1.cost_)
cost_avgs = [np.mean(cost_ary[i]) for i in batches]
plt.plot(range(len(cost_avgs)), cost_avgs, color='red')
plt.ylim([0, 6000])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.tight_layout()
#plt.savefig('./figures/cost2.png', dpi=300)
plt.show()

training_accuracy=get_accuracy(nn1, x_train, y_train)
print('Training accuracy: %.2f%%' %training_accuracy)

test_accuracy=get_accuracy(nn1, x_test, y_test)
print('Test accuracy: %.2f%%' %test_accuracy)
# Out:
# Epoch: 100/100
# Training accuracy: 92.98%
# Test accuracy: 91.93%
# Training accuracy: 92.98%
# Test accuracy: 91.93%

# %% [markdown]
# ### Misclassified Sample

# %%
y_test_pred = nn1.predict(x_test)

miscl_img = x_test[y_test != y_test_pred][:10]
correct_lab = y_test[y_test != y_test_pred][:10]
miscl_lab= y_test_pred[y_test != y_test_pred][:10]

fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(10):
    img = miscl_img[i].reshape(num_px, num_px, 3)
    ax[i].imshow(img)
    ax[i].set_title('%d) t: %d p: %d' % (i+1, correct_lab[i], miscl_lab[i]))

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import roc_auc_score, log_loss, accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix, recall_score, precision_score
from sklearn.preprocessing import binarize, PolynomialFeatures
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.calibration import calibration_curve

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
def encoder(dataset, catFeatures, qtyFeatures):
  dataset = dataset[catFeatures + qtyFeatures]
  dataset_encoded = pd.get_dummies(dataset, 
                                   columns = catFeatures, 
                                   drop_first = True)
  
  return(dataset_encoded)

def plot_auc_curve(model, X, y):
  try:
      y_pred_prob = model.predict_proba(X)[:,1]
  except:
    d = model.decision_function(X)
    y_pred_prob = np.exp(d) / (1 + np.exp(d))
  
  auc = roc_auc_score(y, y_pred_prob)
  fpr, tpr, thresholds = roc_curve(y, y_pred_prob)
  
  plt.plot(fpr, tpr)
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.title('ROC Curve\n AUC={auc}'.format(auc = auc))
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.grid(True)

def model_training(model, X, y):
  model.fit(X,y)
  
  return(model)

def print_accuracy_metrics(model, X, y, threshold):
  try:
      y_pred_prob = model.predict_proba(X)[:,1]
  except:
    d = model.decision_function(X)
    y_pred_prob = np.exp(d) / (1 + np.exp(d))
  y_pred_class = binarize([y_pred_prob], threshold)[0]
  
  print("Accurcay:", accuracy_score(y, y_pred_class))
  print("AUC:", roc_auc_score(y, y_pred_prob))
  print("Log Loss:", log_loss(y, y_pred_prob))
  print("Confusion Matrix:\n", confusion_matrix(y, y_pred_class))
  print("Recall:", recall_score(y, y_pred_class))
  print("Precision:", precision_score(y, y_pred_class))


def Find_Optimal_Cutoff(model, X, y):
  try:
    y_pred_prob = model.predict_proba(X)[:,1]
  except:
    d = model.decision_function(X)
    y_pred_prob = np.exp(d) / (1 + np.exp(d))
    
  fpr, tpr, threshold = roc_curve(y, y_pred_prob)
  i = np.arange(len(tpr)) 
  roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'threshold' : pd.Series(threshold, index=i)})
  roc_t = roc.loc[(roc.tf-0).abs().argsort()[:1]]
  
  print("Optimal Cutoff:", roc_t['threshold'].values)
  return(roc_t['threshold'].values)
  
def feature_importance(model, X):
  importances = model.feature_importances_
  std = np.std([tree.feature_importances_ for tree in model.estimators_],
               axis=0)
  indices = np.argsort(importances)[::-1]

  # Print the feature ranking
  print("Feature ranking:")

  for f in range(X.shape[1]):
      print("%d. %s (%f)" % (f + 1, X.columns[indices[f]], importances[indices[f]]))

  # Plot the feature importances of the forest
  plt.figure()
  plt.title("Feature importances")
  plt.bar(range(X.shape[1]), importances[indices],
          color="r", yerr=std[indices], align="center")
  plt.xticks(range(X.shape[1]), indices)
  plt.xlim([-1, X.shape[1]])
  plt.show()

# Plot calibration plots
def plot_calibration(y_true, y_prob, n_bins, model_name):
  plt.figure(figsize=(10, 10))
  ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
  ax2 = plt.subplot2grid((3, 1), (2, 0))

  ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
  fraction_of_positives, mean_predicted_value = \
        calibration_curve(y_true, y_prob, n_bins=n_bins)

  ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
             label="%s" % (model_name, ))

  ax2.hist(y_pred_prob, range=(0, 1), bins=10, label=model_name,
             histtype="step", lw=2)

  ax1.set_ylabel("Fraction of positives")
  ax1.set_ylim([-0.05, 1.05])
  ax1.legend(loc="lower right")
  ax1.set_title('Calibration plots')

  ax2.set_xlabel("Mean predicted value")
  ax2.set_ylabel("Count")
  ax2.legend(loc="upper right", ncol=2)

  plt.tight_layout()
  plt.show()

# %% [markdown]
# # MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
NN = MLPClassifier(solver='adam', alpha=0.01,
                     hidden_layer_sizes=(30,20,10), random_state=1, max_iter=100, activation='logistic')

 

model_training(NN, x_train, y_train)
print("\n********************************")
print("\nTraining Error")
print_accurcay_metrics(NN, x_train, y_train, 0.5)

 

print("\n********************************")
print("Test Error")
print_accurcay_metrics(NN, x_test, y_test, 0.5)
# Out:
# ********************************
#
# Training Error
# Accurcay: 0.9100498338870432
# AUC: 0.9287495376509405
# Log Loss: 0.2694865210616023
# Confusion Matrix:
#  [[11379   720]
#  [ 1446 10535]]
# Recall: 0.8793089057674651
# Precision: 0.9360284318080853
#
# ********************************
# Test Error
# Accurcay: 0.8980939329762053
# AUC: 0.9189462220793042
# Log Loss: 0.2896904472556386
# Confusion Matrix:
#  [[3673  265]
#  [ 553 3536]]
# Recall: 0.8647591098067987
# Precision: 0.9302815048671402

# %%
from sklearn.neural_network import MLPClassifier
NN = MLPClassifier(solver='adam', alpha=0.01,
                     hidden_layer_sizes=(30,20,10), random_state=1, max_iter=400, activation='logistic')

 

model_training(NN, x_train, y_train)
print("\n********************************")
print("\nTraining Error")
print_accurcay_metrics(NN, x_train, y_train, 0.5)

 

print("\n********************************")
print("Test Error")
print_accurcay_metrics(NN, x_test, y_test, 0.5)
# Out:
# ********************************
#
# Training Error
# Accurcay: 0.9100498338870432
# AUC: 0.9287495376509405
# Log Loss: 0.2694865210616023
# Confusion Matrix:
#  [[11379   720]
#  [ 1446 10535]]
# Recall: 0.8793089057674651
# Precision: 0.9360284318080853
#
# ********************************
# Test Error
# Accurcay: 0.8980939329762053
# AUC: 0.9189462220793042
# Log Loss: 0.2896904472556386
# Confusion Matrix:
#  [[3673  265]
#  [ 553 3536]]
# Recall: 0.8647591098067987
# Precision: 0.9302815048671402

# %% [markdown]
# # Logistic Regression

# %%
logreg = LogisticRegression()
model_training(logreg, x_train, y_train)

plot_auc_curve(logreg, x_test, y_test)
Find_Optimal_Cutoff(logreg, x_test, y_test)
print("\n********************************")
print("\nTraining Error")
print_accurcay_metrics(logreg, x_train, y_train, 0.5)
print("\n********************************")
print("Test Error")
print_accurcay_metrics(logreg, x_test, y_test, 0.5)
# Out:
# Optimal Cutoff: [0.3265201]
#
# ********************************
#
# Training Error
# Accurcay: 0.9439784053156146
# AUC: 0.9807846154515842
# Log Loss: 0.17489093835380382
# Confusion Matrix:
#  [[11705   394]
#  [  955 11026]]
# Recall: 0.9202904598948335
# Precision: 0.9654991243432575
#
# ********************************
# Test Error
# Accurcay: 0.8963498193596612
# AUC: 0.9301985867768707
# Log Loss: 0.3433125503902966
# Confusion Matrix:
#  [[3712  226]
#  [ 606 3483]]
# Recall: 0.8517975055025678
# Precision: 0.9390671339983823

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble  import GradientBoostingClassifier
gbt = GradientBoostingClassifier(n_estimators=100, learning_rate= 0.15)
model_training(gbt, x_train, y_train)
print("\n********************************")
print("\nTraining Error")
print_accurcay_metrics(gbt, x_train, y_train, 0.5)
print("\n********************************")
print("Test Error")
print_accurcay_metrics(gbt, x_test, y_test, 0.5)
# Out:
# ********************************
#
# Training Error
# Accurcay: 0.9760382059800664
# AUC: 0.997871588689696
# Log Loss: 0.09986656770891165
# Confusion Matrix:
#  [[12056    43]
#  [  534 11447]]
# Recall: 0.9554294299307237
# Precision: 0.9962576153176675
#
# ********************************
# Test Error
# Accurcay: 0.962003239068145
# AUC: 0.9947234221407607
# Log Loss: 0.12742901743561597
# Confusion Matrix:
#  [[3901   37]
#  [ 268 3821]]
# Recall: 0.9344583027635118
# Precision: 0.9904095386210472

# %%
from sklearn.ensemble  import GradientBoostingClassifier
gbt1 = GradientBoostingClassifier(n_estimators=150, learning_rate= 0.15)
model_training(gbt1, x_train, y_train)
print("\n********************************")
print("\nTraining Error")
print_accurcay_metrics(gbt1, x_train, y_train, 0.5)
print("\n********************************")
print("Test Error")
print_accurcay_metrics(gbt1, x_test, y_test, 0.5)
# Out:
# ********************************
#
# Training Error
# Accurcay: 0.9858388704318937
# AUC: 0.999266798570972
# Log Loss: 0.06433776499297483
# Confusion Matrix:
#  [[12072    27]
#  [  314 11667]]
# Recall: 0.9737918370753693
# Precision: 0.9976911236531555
#
# ********************************
# Test Error
# Accurcay: 0.9698517503425937
# AUC: 0.9968844244011575
# Log Loss: 0.09640387323651516
# Confusion Matrix:
#  [[3905   33]
#  [ 209 3880]]
# Recall: 0.9488872584984104
# Precision: 0.9915665729619217

# %% [markdown]
# # AdaBoostClassifier

# %%
adaBoost = AdaBoostClassifier(n_estimators=150)
model_training(adaBoost, x_train, y_train)

plot_auc_curve(adaBoost, x_test, y_test)
Find_Optimal_Cutoff(adaBoost, x_test, y_test)
print("\n********************************")
print("\nTraining Error")
print_accurcay_metrics(adaBoost, x_train, y_train, 0.5)
print_accurcay_metrics(adaBoost, x_test, y_test, 0.5)
# Out:
# Optimal Cutoff: [0.49711388]
#
# ********************************
#
# Training Error
# Accurcay: 0.9620431893687708
# AUC: 0.9899642185616385
# Log Loss: 0.5933498226341877
# Confusion Matrix:
#  [[12000    99]
#  [  815 11166]]
# Recall: 0.9319756280777899
# Precision: 0.9912117177097204
# Accurcay: 0.9466799551513642
# AUC: 0.9716598348006227
# Log Loss: 0.5941402286581511
# Confusion Matrix:
#  [[3882   56]
#  [ 372 3717]]
# Recall: 0.909024211298606
# Precision: 0.9851576994434137

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
rf = RandomForestClassifier(n_estimators=600, 
                            criterion='gini', 
                            max_features='sqrt',
                            n_jobs=-1)
model_training(rf, x_train, y_train)

 

plot_auc_curve(rf, x_test, y_test)
Find_Optimal_Cutoff(rf, x_test, y_test)
# Out:
# Optimal Cutoff: [0.55166667]
# array([0.55166667])

# %%
print("\n********************************")
print("\nTraining Error")
print_accuracy_metrics(rf, x_train, y_train, 0.5)
print("\n********************************")
print("Test Error")
print_accuracy_metrics(rf, x_test, y_test, 0.5)
# Out:
# ********************************
#
# Training Error
# Accurcay: 1.0
# AUC: 1.0
# Log Loss: 0.02197102669986089
# Confusion Matrix:
#  [[12099     0]
#  [    0 11981]]
# Recall: 1.0
# Precision: 1.0
#
# ********************************
# Test Error
# Accurcay: 0.9860470910676467
# AUC: 0.9986206784767714
# Log Loss: 0.07147149124747355
# Confusion Matrix:
#  [[3863   75]
#  [  37 4052]]
# Recall: 0.9909513328442162
# Precision: 0.9818269929731039

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
rf1 = RandomForestClassifier(n_estimators=500, 
                            criterion='gini', 
                            max_features='sqrt',
                            n_jobs=-1)
model_training(rf1, x_train, y_train)

 

plot_auc_curve(rf1, x_test, y_test)
Find_Optimal_Cutoff(rf1, x_test, y_test)
# Out:
# Optimal Cutoff: [0.556]
# array([0.556])

# %%
print("\n********************************")
print("\nTraining Error")
print_accuracy_metrics(rf1, x_train, y_train, 0.5)

 

print("\n********************************")
print("Test Error")
print_accuracy_metrics(rf1, x_test, y_test, 0.5)
# Out:
# ********************************
#
# Training Error
# Accurcay: 1.0
# AUC: 1.0
# Log Loss: 0.021758208959550846
# Confusion Matrix:
#  [[12099     0]
#  [    0 11981]]
# Recall: 1.0
# Precision: 1.0
#
# ********************************
# Test Error
# Accurcay: 0.9856733524355301
# AUC: 0.9986500838814787
# Log Loss: 0.0711119528988972
# Confusion Matrix:
#  [[3864   74]
#  [  41 4048]]
# Recall: 0.9899730985571045
# Precision: 0.9820475497331392

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import itertools
from glob import glob
import PIL
from PIL import Image
from scipy import ndimage 
import scipy
import sys

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.layers.normalization import BatchNormalization

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Displaying sample training images:

# %%
img_positive = 'C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/training/Positive/1.jpg'
image =  plt.imread(img_positive)
image = np.asarray(image)
plt.imshow(image)

# %%
img_positive = 'C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/training/Negative/1.jpg'
image =  plt.imread(img_positive)
image = np.asarray(image)
plt.imshow(image)

# %% [markdown]
# ### Preprocessing the training data using standardization

# %%
train_data_dir_positive = "C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/training/Positive/"
train_data_dir_negative = "C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/training/Negative/"

crack_Negative_df = pd.DataFrame(columns=( 'path', 'image', 'label'),index=np.arange(0,16037))
crack_Positive_df = pd.DataFrame(columns=( 'path', 'image', 'label'),index=np.arange(0,16070))

imageid_path_dict_Negative = np.array([x for x in glob(os.path.join(train_data_dir_negative, '*.jpg'))])
imageid_path_dict_Positive = np.array([x for x in glob(os.path.join(train_data_dir_positive, '*.jpg'))])

print(len(imageid_path_dict_Negative))
# Out:
# 16037

# %%
crack_Negative_df['path']=imageid_path_dict_Negative
crack_Negative_df['label']=0
crack_Negative_df['image']=crack_Negative_df['path'].map(lambda x: np.asarray(Image.open(x).resize((75,100))))

crack_Positive_df['path']=imageid_path_dict_Positive
crack_Positive_df['label']=1
crack_Positive_df['image']=crack_Positive_df['path'].map(lambda x: np.asarray(Image.open(x).resize((75,100))))

print("Negative:",crack_Negative_df["image"][0].shape)
print("Positive:",crack_Positive_df["image"][0].shape)

print(imageid_path_dict_Negative.shape,imageid_path_dict_Positive.shape)

crack_df = crack_Negative_df.append(crack_Positive_df)  
crack_df.reset_index(drop=True,inplace=True) 
print(crack_df.shape)
# Out:
# Negative: (100, 75, 3)
# Positive: (100, 75, 3)
# (16037,) (16070,)
# (32107, 3)

# %%
features=crack_df.drop(columns=['label'],axis=1)
target=crack_df["label"]

x_train_o, x_test_o, y_train, y_test = train_test_split(features, target, test_size=0.20,random_state=1)

x_train = np.asarray(x_train_o['image'].tolist())
x_test = np.asarray(x_test_o['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_train_mean)/x_train_std

# Reshape image in 3 dimensions (height = 100px, width = 100px , canal = 3)
x_train = x_train.reshape(x_train.shape[0], *(75, 100, 3))
x_test = x_test.reshape(x_test.shape[0], *(75, 100, 3))

# %% [markdown]
# ### Using Keras sequential model with sigmoid as activation function

# %%
model1_stand = Sequential()

model1_stand.add(Conv2D(32, (3, 3), input_shape = (75, 100, 3), activation = 'relu',padding = 'same'))
model1_stand.add(MaxPooling2D(pool_size = (2, 2)))
model1_stand.add(Dropout(0.25))


model1_stand.add(Conv2D(64, (3, 3), padding = 'same',activation = 'relu'))
model1_stand.add(MaxPooling2D(pool_size = (2, 2)))
model1_stand.add(Dropout(0.25))


model1_stand.add(Flatten())
model1_stand.add(Dense(units = 128, activation = 'relu'))
model1_stand.add(Dense(units = 1, activation = 'sigmoid'))

model1_stand.summary()
model1_stand.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

model1_stand.fit(x_train, y_train, validation_split=0.1,epochs=20, batch_size=256)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 75, 100, 32)       896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 50, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 50, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 25, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 25, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3686528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,706,049
# Trainable params: 3,706,049
# Non-trainable params: 0
# _________________________________________________________________
# Train on 23116 samples, validate on 2569 samples
# Epoch 1/20
# 23116/23116 [==============================] - 38s 2ms/step - loss: 0.3154 - accuracy: 0.8850 - val_loss: 0.2224 - val_accuracy: 0.9307
# Epoch 2/20
# 23116/23116 [==============================] - 21s 923us/step - loss: 0.0406 - accuracy: 0.9866 - val_loss: 0.0366 - val_accuracy: 0.9910
# Epoch 3/20
# 23116/23116 [==============================] - 14s 608us/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.0298 - val_accuracy: 0.9895
# Epoch 4/20
# 23116/23116 [==============================] - 16s 706us/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.0167 - val_accuracy: 0.9946
# Epoch 5/20
# 23116/23116 [==============================] - 15s 637us/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.0154 - val_accuracy: 0.9942
# Epoch 6/20
# 23116/23116 [==============================] - 14s 596us/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.0246 - val_accuracy: 0.9903
# Epoch 7/20
# 23116/23116 [==============================] - 14s 599us/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0105 - val_accuracy: 0.9969
# Epoch 8/20
# 23116/23116 [==============================] - 14s 599us/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0141 - val_accuracy: 0.9957
# Epoch 9/20
# 23116/23116 [==============================] - 14s 595us/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0151 - val_accuracy: 0.9949
# Epoch 10/20
# 23116/23116 [==============================] - 14s 606us/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0085 - val_accuracy: 0.9977
# Epoch 11/20
# 23116/23116 [==============================] - 14s 606us/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0266 - val_accuracy: 0.9918
# Epoch 12/20
# 23116/23116 [==============================] - 14s 599us/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0287 - val_accuracy: 0.9903
# Epoch 13/20
# 23116/23116 [==============================] - 14s 605us/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0450 - val_accuracy: 0.9852
# Epoch 14/20
# 23116/23116 [==============================] - 14s 597us/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0100 - val_accuracy: 0.9961
# Epoch 15/20
# 23116/23116 [==============================] - 14s 603us/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0226 - val_accuracy: 0.9934
# Epoch 16/20
# 23116/23116 [==============================] - 14s 599us/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0179 - val_accuracy: 0.9938
# Epoch 17/20
# 23116/23116 [==============================] - 14s 597us/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0270 - val_accuracy: 0.9918
# Epoch 18/20
# 23116/23116 [==============================] - 16s 708us/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0091 - val_accuracy: 0.9969
# Epoch 19/20
# 23116/23116 [==============================] - 17s 752us/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0318 - val_accuracy: 0.9910
# Epoch 20/20
# 23116/23116 [==============================] - 14s 605us/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0126 - val_accuracy: 0.9969

# %%
history = model1_stand.history
fig, ax = plt.subplots()

ax.plot(history.history['accuracy'],label='training accuracy')
ax.plot(history.history['val_accuracy'],label='val accuracy')

ax.set_title('model accuracy',{'size':16})
ax.set_xlabel('epoch',{'size':16})
ax.set_ylabel('accuracy',{'size':16})
              
plt.tick_params(labelsize=14)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(history.history['loss'],label='training loss')
ax.plot(history.history['val_loss'],label='val loss')

ax.set_title('model loss',{'size':16})
ax.set_xlabel('epoch',{'size':16})
ax.set_ylabel('loss',{'size':16})
              
plt.tick_params(labelsize=14)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
test_loss, test_acc = model1_stand.evaluate(x_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# Test accuracy: 0.9912799596786499

# %% [markdown]
# ### ImageGenerator

# %%
model_ig = Sequential()

model_ig.add(Conv2D(16, (3, 3), input_shape = (75, 100, 3),padding='same', activation = 'relu'))
model_ig.add(MaxPooling2D(pool_size = (2, 2)))
model_ig.add(Conv2D(32, (3, 3), padding = 'same',activation = 'relu'))
model_ig.add(MaxPooling2D(pool_size = (2, 2)))
model_ig.add(Conv2D(64, (3, 3), padding = 'same',activation = 'relu'))
model_ig.add(MaxPooling2D(pool_size = (2, 2)))
model_ig.add(Flatten())
model_ig.add(Dense(units = 128, activation = 'relu'))
model_ig.add(Dense(units = 1, activation = 'sigmoid'))

model_ig.summary()
model_ig.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

datagen = ImageDataGenerator(validation_split=0.20)

datagen.fit(x_train)

training_generator = datagen.flow(x_train, y_train, batch_size=128)

result = model_ig.fit_generator(training_generator, epochs=20)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 75, 100, 16)       448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 50, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 25, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 12, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6912)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               884864
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 908,577
# Trainable params: 908,577
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 201/201 [==============================] - 23s 115ms/step - loss: 0.0831 - accuracy: 0.9680
# Epoch 2/20
# 201/201 [==============================] - 8s 41ms/step - loss: 0.0200 - accuracy: 0.9932
# Epoch 3/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0137 - accuracy: 0.9953
# Epoch 4/20
# 201/201 [==============================] - 8s 39ms/step - loss: 0.0118 - accuracy: 0.9962
# Epoch 5/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0104 - accuracy: 0.9967
# Epoch 6/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0076 - accuracy: 0.9975
# Epoch 7/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0065 - accuracy: 0.9978
# Epoch 8/20
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 9/20
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 10/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0041 - accuracy: 0.9989
# Epoch 11/20
# 201/201 [==============================] - 8s 37ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 12/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 13/20
# 201/201 [==============================] - 8s 37ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 14/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 15/20
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 16/20
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0018 - accuracy: 0.9994 0s - loss: 0.0019 - accura
# Epoch 17/20
# 201/201 [==============================] - 8s 38ms/step - loss: 4.6689e-04 - accuracy: 0.9999
# Epoch 18/20
# 201/201 [==============================] - 8s 38ms/step - loss: 2.7268e-04 - accuracy: 0.9999
# Epoch 19/20
# 201/201 [==============================] - 8s 39ms/step - loss: 9.4099e-05 - accuracy: 1.0000
# Epoch 20/20
# 201/201 [==============================] - 8s 38ms/step - loss: 4.4561e-05 - accuracy: 1.0000

# %%
test_loss, test_acc = model_ig.evaluate(x_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# Test accuracy: 0.9970414042472839

# %% [markdown]
# ReLu used as an activation for model2_ig sequential model

# %%
model2_ig = Sequential()

model2_ig.add(Conv2D(16, (3, 3), input_shape = (75, 100, 3),padding='same', activation = 'relu'))
model2_ig.add(MaxPooling2D(pool_size = (2, 2)))
model2_ig.add(Conv2D(32, (3, 3), padding = 'same',activation = 'relu'))
model2_ig.add(MaxPooling2D(pool_size = (2, 2)))
model2_ig.add(Conv2D(64, (3, 3), padding = 'same',activation = 'relu'))
model2_ig.add(MaxPooling2D(pool_size = (2, 2)))
model2_ig.add(Flatten())
model2_ig.add(Dense(units = 128, activation = 'relu'))
model2_ig.add(Dense(units = 1))

model2_ig.summary()
model2_ig.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    
datagen_new = ImageDataGenerator(validation_split=0.20,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5)

datagen_new.fit(x_train)

training_generator_new = datagen_new.flow(x_train, y_train, batch_size=128)

result = model2_ig.fit_generator(training_generator_new, epochs=30)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 75, 100, 16)       448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 50, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 25, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 12, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6912)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               884864
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 908,577
# Trainable params: 908,577
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 201/201 [==============================] - 41s 206ms/step - loss: 0.1934 - accuracy: 0.6106
# Epoch 2/30
# 201/201 [==============================] - 34s 170ms/step - loss: 0.0430 - accuracy: 0.5475
# Epoch 3/30
# 201/201 [==============================] - 34s 167ms/step - loss: 0.0429 - accuracy: 0.5433
# Epoch 4/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0634 - accuracy: 0.5434
# Epoch 5/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0355 - accuracy: 0.5367
# Epoch 6/30
# 201/201 [==============================] - 33s 165ms/step - loss: 0.0359 - accuracy: 0.5333
# Epoch 7/30
# 201/201 [==============================] - 34s 167ms/step - loss: 0.0489 - accuracy: 0.5364
# Epoch 8/30
# 201/201 [==============================] - 34s 171ms/step - loss: 0.0488 - accuracy: 0.5206
# Epoch 9/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0400 - accuracy: 0.5296
# Epoch 10/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.1344 - accuracy: 0.5409
# Epoch 11/30
# 201/201 [==============================] - 34s 167ms/step - loss: 0.0409 - accuracy: 0.5384
# Epoch 12/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0449 - accuracy: 0.5276
# Epoch 13/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.1160 - accuracy: 0.5041
# Epoch 14/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.1714 - accuracy: 0.4714
# Epoch 15/30
# 201/201 [==============================] - 34s 167ms/step - loss: 0.0516 - accuracy: 0.5112
# Epoch 16/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0400 - accuracy: 0.5233
# Epoch 17/30
# 201/201 [==============================] - 34s 167ms/step - loss: 0.0547 - accuracy: 0.5340
# Epoch 18/30
# 201/201 [==============================] - 35s 172ms/step - loss: 0.0366 - accuracy: 0.5227
# Epoch 19/30
# 201/201 [==============================] - 35s 173ms/step - loss: 0.0304 - accuracy: 0.5180
# Epoch 20/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0464 - accuracy: 0.5356
# Epoch 21/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.1995 - accuracy: 0.5184
# Epoch 22/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.1280 - accuracy: 0.5040
# Epoch 23/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0685 - accuracy: 0.5208
# Epoch 24/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0520 - accuracy: 0.5142
# Epoch 25/30
# 201/201 [==============================] - 33s 167ms/step - loss: 0.1429 - accuracy: 0.4381
# Epoch 26/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.4771 - accuracy: 0.5083
# Epoch 27/30
# 201/201 [==============================] - 34s 170ms/step - loss: 0.0508 - accuracy: 0.5394
# Epoch 28/30
# 201/201 [==============================] - 35s 174ms/step - loss: 0.0460 - accuracy: 0.5187
# Epoch 29/30
# 201/201 [==============================] - 35s 172ms/step - loss: 0.0407 - accuracy: 0.5071
# Epoch 30/30
# 201/201 [==============================] - 33s 166ms/step - loss: 0.0365 - accuracy: 0.5292

# %%
test_loss, test_acc = model2_ig.evaluate(x_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# Test accuracy: 0.49563997983932495

# %% [markdown]
# Sigmoid added as activation function in the model2_ig sequential model

# %%
model2_ig = Sequential()

model2_ig.add(Conv2D(16, (3, 3), input_shape = (75, 100, 3),padding='same', activation = 'relu'))
model2_ig.add(MaxPooling2D(pool_size = (2, 2)))
model2_ig.add(Conv2D(32, (3, 3), padding = 'same',activation = 'relu'))
model2_ig.add(MaxPooling2D(pool_size = (2, 2)))
model2_ig.add(Conv2D(64, (3, 3), padding = 'same',activation = 'relu'))
model2_ig.add(MaxPooling2D(pool_size = (2, 2)))
model2_ig.add(Flatten())
model2_ig.add(Dense(units = 128, activation = 'relu'))
model2_ig.add(Dense(units = 1))
model2_ig.add(Dense(units = 1, activation = 'sigmoid'))

model2_ig.summary()
model2_ig.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    
datagen_new = ImageDataGenerator(validation_split=0.20,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5)

datagen_new.fit(x_train)

training_generator_new = datagen_new.flow(x_train, y_train, batch_size=128)

result = model2_ig.fit_generator(training_generator_new, epochs=30)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 75, 100, 16)       448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 37, 50, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 18, 25, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 18, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 9, 12, 64)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6912)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               884864
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 908,579
# Trainable params: 908,579
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 201/201 [==============================] - 46s 227ms/step - loss: 0.0920 - accuracy: 0.9608s - loss: 0
# Epoch 2/30
# 201/201 [==============================] - 44s 220ms/step - loss: 0.0284 - accuracy: 0.9907
# Epoch 3/30
# 201/201 [==============================] - 36s 178ms/step - loss: 0.0216 - accuracy: 0.9928
# Epoch 4/30
# 201/201 [==============================] - 34s 170ms/step - loss: 0.0231 - accuracy: 0.9924
# Epoch 5/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0221 - accuracy: 0.9925
# Epoch 6/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0194 - accuracy: 0.9937
# Epoch 7/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0195 - accuracy: 0.9938
# Epoch 8/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0196 - accuracy: 0.9932
# Epoch 9/30
# 201/201 [==============================] - 34s 170ms/step - loss: 0.0190 - accuracy: 0.9937
# Epoch 10/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0172 - accuracy: 0.9944
# Epoch 11/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0172 - accuracy: 0.9949
# Epoch 12/30
# 201/201 [==============================] - 34s 170ms/step - loss: 0.0173 - accuracy: 0.9944
# Epoch 13/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0147 - accuracy: 0.9956
# Epoch 14/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0177 - accuracy: 0.9940
# Epoch 15/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0157 - accuracy: 0.9954
# Epoch 16/30
# 201/201 [==============================] - 35s 172ms/step - loss: 0.0141 - accuracy: 0.9952
# Epoch 17/30
# 201/201 [==============================] - 34s 171ms/step - loss: 0.0142 - accuracy: 0.9953
# Epoch 18/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0162 - accuracy: 0.9945
# Epoch 19/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0144 - accuracy: 0.9948
# Epoch 20/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0152 - accuracy: 0.9952
# Epoch 21/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0126 - accuracy: 0.9963
# Epoch 22/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0145 - accuracy: 0.9952
# Epoch 23/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0139 - accuracy: 0.9954
# Epoch 24/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0124 - accuracy: 0.9963
# Epoch 25/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0126 - accuracy: 0.9961
# Epoch 26/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0117 - accuracy: 0.9960
# Epoch 27/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0133 - accuracy: 0.9959
# Epoch 28/30
# 201/201 [==============================] - 34s 169ms/step - loss: 0.0124 - accuracy: 0.9962
# Epoch 29/30
# 201/201 [==============================] - 34s 167ms/step - loss: 0.0114 - accuracy: 0.9960
# Epoch 30/30
# 201/201 [==============================] - 34s 168ms/step - loss: 0.0116 - accuracy: 0.9961

# %%
test_loss, test_acc = model2_ig.evaluate(x_test,  y_test, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# Test accuracy: 0.9922142624855042

# %% [markdown]
# ### Testing the model

# %%
import glob
import numpy as np
from keras.preprocessing import image
inp = image.load_img("C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test/242061700105601.png",target_size=(75,100,3))
#inp = img_to_array(inp)
plt.imshow(inp)
img = np.expand_dims(inp, axis=0)
img = (img - x_train_mean)/x_train_std
output = model_ig.predict(img)
print(output)
if output[0] > 0.8:
    print("cracked")
else:
    print('not cracked')
# Out:
# [[4.004571e-06]]
# not cracked

# %% [markdown]
# #### Labelling the class for the test set images with predictions based on the ImageGenerator model:

# %%
import glob
import numpy as np
from keras.preprocessing import image
test_data = 'C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test'
result_array = []
for img in glob.glob('C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test/*.*'):
  test_image = image.load_img(img, target_size = (75, 100, 3))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  test_image = ((test_image - x_train_mean) / x_train_std)
  result = model_ig.predict(test_image)
  if result[0][0] > 0.8:
    print(img + '===\n\n' + 'crack')
    prediction = 'crack'
    result_array.append(prediction)
  else:
    print(img + '===\n\n' + 'intact')
    prediction = 'nocrack'
    result_array.append(prediction)
# Out:
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000016480768558.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000094138882661.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\100010347143101.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000228345963509.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\10002760868742.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000324142734685.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000502603639355.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000680161643094.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1000777041608516.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1001169259026054.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1001331309398662.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1001470542104712.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1001567159154475.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1001765803830121.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1001813990290808.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1002176622750587.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\100218589112962.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1002293629509383.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1002456236828977.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1002737927571484.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003000195528864.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003011347500746.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003068185138241.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003443492244003.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003557972398882.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003811750112429.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1003911505089218.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\100414884507915.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1004539611112233.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1005105141165163.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1005142076728330.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1005173926339201.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1005196592117911.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1005705916066314.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1006034448838016.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1006609203421792.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1006709712994735.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\100674892849406.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1006901559474100.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1007307227790931.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1007354566939277.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1007798281840707.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1007996080564288.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1008107111227372.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1008171258427007.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1008383552085473.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1008633147610234.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\100863428045540.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1009015077842413.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1009610229194911.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1010071041146214.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1010265168683783.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\101029680875421.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1010416533651186.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1010444971639026.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1010608023623157.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1010952036496784.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011053417335275.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011284834865130.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011331136123914.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011399361649611.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011419378665852.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011428298993606.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1011688648681388.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1012381049317659.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1012531295068342.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\101274825930907.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\101276404218600.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1013188281911819.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1013256833374209.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1013263950320460.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1013501744715983.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1013558286535260.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1014057488685352.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1014609854583248.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1014890221518151.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1014920341911477.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1015168216349652.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\101520420806697.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\10158635641126.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1016464831033549.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1017439149430722.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1017649978290118.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1017713224157120.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018177031372768.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018208859561553.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018211268948463.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018267848438937.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018417649272125.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018643807075586.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1018897850390162.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1019222911131406.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1019281602491433.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\10197186744847.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\101982690651512.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1019959579471546.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1020124024937551.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102014516397056.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1020195560902437.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1020275567842999.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102028860534776.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102038955468366.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1020533210384539.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1020998957810039.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1021094860614972.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1021329549658931.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1021571855714350.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102171404669264.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1021854711801914.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1021968617099661.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1022039397195566.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1022257256400904.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1022610230832438.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023125852861876.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023362891451001.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023466084561659.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023560350375381.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023592435857211.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023647856545897.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023655718591112.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1023958922328362.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1024263230885973.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1024327103317106.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102447742495053.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1024583030573305.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1024659615175773.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1025179365642125.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1025186357632395.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1025494931425768.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1025827436336773.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1026137221387728.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1026167598771743.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1026273887274405.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1026664970532308.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1026907431258282.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1027106748947721.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1027128200043424.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1027134275487031.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1027399837212409.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102761317000232.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1027950992078439.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1028040261452230.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1028241648956402.png===
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102831403162638.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1028943467124482.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1029388840526031.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\102971489305831.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1029716557454810.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1030100800539944.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1030333524161230.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1030348180429542.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1030709953530364.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1030837378517056.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\103158479541262.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\103158517981868.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1031768975383425.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1031927136746115.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1032020983595745.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1032157599493068.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1032341182468437.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1032519539571725.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1032664115415218.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1032828001554600.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1033318792074808.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1033400313856555.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1033896186005826.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1034671279580357.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\103498708397755.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035133436220962.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035264215402492.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035348334490077.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035383035826779.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\103542730492901.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035644495365359.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035813174619660.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035856092364324.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1035928048692787.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1036148738569786.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1036317230021484.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1036545699095162.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1036555842968707.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1036689164188281.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1037061527870524.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1037350809924707.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1037380274001592.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1038428321939909.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1038664936606642.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1038758231327974.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1038995458033124.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1039065790962364.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1039218637877571.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1039630573317746.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1040108699715274.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1040230402106640.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1040519910097289.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1040592974533970.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1040636658278872.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1041212434944039.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1041238485119814.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1041372440030160.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1041536974078854.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\104168827050522.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1041812205652721.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1041975818842341.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1042026327466404.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1042386933467721.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1042953891843063.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1043300070394572.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1043491441778757.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1043906079126198.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1044077006021775.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1044302097228442.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1044676543049795.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\104480076006649.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1044891993241232.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1044941830435951.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1045607512272668.png===
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1045743690159289.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\104582394889.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1045909960548301.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1046077855143703.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1046090859735975.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1046182726363256.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1046328362509580.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1046538661739815.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1047077961636648.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1047086207938129.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1047197278588377.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1047548499940284.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1047571272492181.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\104810661713829.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1048132999459635.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1048507976116950.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1048654569933823.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1048736028578849.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1049041503665068.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1049231865011727.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1049597079801797.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1050399642530923.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1050681088732172.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1050909821437927.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1051209052729324.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1051327397665671.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1051399675464375.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1051752670831591.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1051828691060490.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1051846767929742.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052527262173833.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052550739243061.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052557565630790.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052766641287639.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052920341788036.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052923545115399.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1052960470589596.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1053277720303521.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1053289445070826.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1053291438390620.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1053497394056885.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1053698105121847.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1053856741680723.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1054353983887563.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1054594103919953.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1054649073160784.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1054796368613822.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1055112887645382.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1055197627037713.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1055268219283261.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1055482834727188.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1055992063867228.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1056195516858969.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1056298833807871.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1056441428363583.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1056570402688093.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1056985265517321.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\105813482581640.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1058892371111688.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1059277125647286.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1059411916728.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1059568926407906.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1059833863003434.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1060165037331902.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1060260782650306.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1060484267335324.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1060503194375872.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1061275632259134.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1061370277472854.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1061437607982661.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1061935240532672.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1061969695431218.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1062196994315805.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1063379563463447.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1063399957524625.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1063861310193747.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1064109411475531.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1064149525210081.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1064608314515328.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1064634118482028.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1064902229280961.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1065184229781287.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\106523340099686.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1065461651121300.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1065465122985906.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1065913239641707.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\106591474889621.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1066111608548637.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1066202590066780.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1066313615702408.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1066534517130610.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1066715442843831.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1066782995066367.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\106690868540626.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1067264337993994.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1067290557729517.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1067596016288634.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1067954568346239.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\106822971686113.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1068806808981436.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1068874355295874.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1068940534091348.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1068993034455883.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\106910708285967.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1069289846251368.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\106930729798879.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1069416561175132.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1069416710291721.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1069685134980629.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1070111036361215.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1070335052159040.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1070474861855111.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1070477812714352.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1070680772600281.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1071533701275056.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1071734721089401.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072234884439319.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072255612335720.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072269224300054.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072269477391273.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072287135953686.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072381738215450.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072764996265007.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1072988309413747.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1073054770258176.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\10730978076665.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1073104980938726.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1073124943650678.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1073369413480898.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1073700646652462.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1074066691460415.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1074345161480729.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1074376653400163.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1074488223002640.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1074491636479158.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1074980316461929.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\1075506803336152.png===
#
# intact
# ...
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\974184792055839.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\974743147976508.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\974837049695011.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\975158058728595.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\976098596748227.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\976394370110307.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\976477448812151.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\976502933573441.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\976957662819162.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\977675796602476.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\978368932177703.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\978450439074914.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\978983157814715.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\978987344628794.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\979106381753437.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\979203607035263.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\979570019522707.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\979752926416960.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\980571791288668.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\980660903125234.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\980681166154114.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\980816305969703.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\9808541501048.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\980865800205636.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\982106072424817.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\982173978291582.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\982509717365361.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\982761453593062.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\983251435975562.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\983287104760578.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\983298552997165.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\983552923926756.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\983581449153409.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\984141236383065.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\984369838943784.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\984417088276285.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\984521950356612.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\984619589858647.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\984840673437673.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\985320943407207.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\985824993709304.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\985899948157447.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\985901969761324.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\985946773991113.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986064779234443.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986066908005695.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986077279039665.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986135847103821.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986420190566723.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986638168355805.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\986689269197957.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\98698423803835.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987005909792796.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987018081454581.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987094429212646.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987213124003492.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987370032724522.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987500980612228.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987584701730666.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\987722697734023.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\988000576937377.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\98816470255360.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\988324856704766.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\988933613046193.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\989110400987582.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\989391478323441.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\989973683480996.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990191679345955.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990214825677022.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990353697929268.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990448762746002.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990489355003255.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990554292118396.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990669733521493.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\990898246816827.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\991062331823505.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99120539926996.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\991307534564135.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99176632478516.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\991893436027857.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\991942596807758.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\992131599391799.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99230243312235.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\992358836532197.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\992605419867142.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99287270677137.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\993241871601801.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99331278365748.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\994032321497350.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\994475863393305.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\994698841402271.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\994773228059563.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\994988421451679.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99517683044292.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\995588458928456.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\995898961371882.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996377898045091.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996543105555991.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996655730971395.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996764594271236.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99679944896889.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996803938174696.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996836257458485.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\996882031496462.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\997391405649940.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\997411423319560.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\99745799560785.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\997705587693472.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\997749952270705.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998037691249182.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998089738179252.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998142349995074.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998213445576875.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998571566265837.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998643968970504.png===
#
# crack
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\998973470469203.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\999190422899601.png===
#
# intact
# C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test\999601573628368.png===
#
# crack

# %% [markdown]
# Exporting the CSV based on the prediction on the best model (based on accuracy scores)

# %%
val_data_dir = "C:/Users/kumar/Data Science Assignment/Final Project/concerete_crack_images/concerete_crack_images/test/"
val_imgs = os.listdir(val_data_dir)
print(len(val_imgs))
test_df = pd.DataFrame(index=np.arange(0,7893))
test_df['image_id']=val_imgs
test_df['predicted_class']=result_array
test_df.to_csv('Image_generator_sequential_output.csv', index=False)
# Out:
# 7893
